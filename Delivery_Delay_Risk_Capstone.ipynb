# %%
# !git clone https://github.com/deeksha31005-spec/delivery-delay-risk-prediction.git
# Out:
# Cloning into 'delivery-delay-risk-prediction'...
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 4 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (4/4), done.

# %%
import os

os.listdir("delivery-delay-risk-prediction")
# Out:
# ['.git', '.gitignore', 'README.md']

# %%
import os

os.makedirs("delivery-delay-risk-prediction/dataset", exist_ok=True)
os.makedirs("delivery-delay-risk-prediction/models", exist_ok=True)
os.makedirs("delivery-delay-risk-prediction/notebooks", exist_ok=True)

print("Project folders created!")
# Out:
# Project folders created!

# %%
import shutil

shutil.copy(
    "/content/dataset_09_delivery_delay_risk.csv",
    "delivery-delay-risk-prediction/dataset/dataset_09_delivery_delay_risk.csv"
)

print("Dataset copied successfully!")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1454/1564631357.py in <cell line: 0>()
#       1 import shutil
#       2
# ----> 3 shutil.copy(
#       4     "/content/dataset_09_delivery_delay_risk.csv",
#       5     "delivery-delay-risk-prediction/dataset/dataset_09_delivery_delay_risk.csv"
#
# /usr/lib/python3.13/shutil.py in copy(src, dst, follow_symlinks)
#     426     if os.path.isdir(dst):
#     427         dst = os.path.join(dst, os.path.basename(src))
# --> 428     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     429     copymode(src, dst, follow_symlinks=follow_symlinks)
#     430     return dst
#
# /usr/lib/python3.13/shutil.py in copyfile(src, dst, follow_symlinks)
#     258         os.symlink(os.readlink(src), dst)
#     259     else:
# --> 260         with open(src, 'rb') as fsrc:
#     261             try:
# ...

# %%
import os

matches = []

for root, dirs, files in os.walk("/content"):
    for file in files:
        if file == "dataset_09_delivery_delay_risk.csv":
            matches.append(os.path.join(root, file))

print("Found files:")
for path in matches:
    print(path)
# Out:
# Found files:

# %%
import os
print(os.listdir("/content"))
# Out:
# ['.config', 'dataset_09_delivery_delay_risk.csv', 'delivery-delay-risk-prediction', 'sample_data']

# %%
import shutil

shutil.copy(
    "/content/dataset_09_delivery_delay_risk.csv",
    "delivery-delay-risk-prediction/dataset/dataset_09_delivery_delay_risk.csv"
)

print("Dataset copied successfully!")
# Out:
# Dataset copied successfully!

# %%
import os

print(os.listdir("delivery-delay-risk-prediction/dataset"))
# Out:
# ['dataset_09_delivery_delay_risk.csv']

# %%
import os

for root, dirs, files in os.walk("delivery-delay-risk-prediction"):
    level = root.replace("delivery-delay-risk-prediction", "").count(os.sep)
    indent = "    " * level
    print(indent + os.path.basename(root) + "/")

    for file in files:
        print("    " * (level + 1) + file)
# Out:
# delivery-delay-risk-prediction/
#     .gitignore
#     README.md
#     dataset/
#         dataset_09_delivery_delay_risk.csv
#     notebooks/
#     .git/
#         HEAD
#         config
#         index
#         packed-refs
#         description
#         refs/
#             heads/
#                 main
#             tags/
#             remotes/
#                 origin/
#                     HEAD
#         hooks/
#             pre-rebase.sample
#             prepare-commit-msg.sample
#             pre-receive.sample
#             commit-msg.sample
#             pre-merge-commit.sample
#             pre-applypatch.sample
#             pre-push.sample
#             push-to-checkout.sample
#             fsmonitor-watchman.sample
#             pre-commit.sample
#             update.sample
#             post-update.sample
#             applypatch-msg.sample
#         branches/
#         objects/
#             pack/
#                 pack-b4698bd2ce1229d4166bc2ca0cbcf21c3400daf8.pack
# ...

# %%
import os

for root, dirs, files in os.walk("/content"):
    for file in files:
        if file.endswith(".ipynb"):
            print(os.path.join(root, file))
